# %%
from google.colab import drive
drive.mount('/content/drive')

# Example: dataset path in Drive
DATA_DIR = "/content/drive/MyDrive/brats2020/"
print("Data directory set to:", DATA_DIR)
# Out:
# Mounted at /content/drive
# Data directory set to: /content/drive/MyDrive/brats2020/

# %%
# Always upgrade pip first
# !pip install --upgrade pip

# Core scientific stack
# !pip install numpy scikit-learn matplotlib

# Medical imaging file handling
# !pip install nibabel

# PyTorch (Colab usually has it, but this ensures latest)
# !pip install torch torchvision torchaudio

# Medical Imaging frameworks
# !pip install monai torchio

# Config management
# !pip install hydra-core

# Experiment tracking (pick one)
# !pip install wandb
# OR
# !pip install tensorboard

# Optional helpers
# !pip install tqdm
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 24.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 24.1.2
#     Uninstalling pip-24.1.2:
#       Successfully uninstalled pip-24.1.2
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 41.9 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.6/52.6 MB 86.4 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [monai]
# ...

# %%
import torch, nibabel, monai, torchio, sklearn, hydra

print("torch:", torch.__version__, "cuda available:", torch.cuda.is_available())
print("nibabel:", nibabel.__version__)
print("monai:", monai.__version__)
print("torchio:", torchio.__version__)
print("scikit-learn:", sklearn.__version__)
# Out:
# torch: 2.8.0+cu126 cuda available: False
# nibabel: 5.3.2
# monai: 1.5.1
# torchio: 0.20.22
# scikit-learn: 1.6.1

# %%
import torch
print("torch version:", torch.__version__)
print("cuda available:", torch.cuda.is_available())
# Out:
# torch version: 2.8.0+cu126
# cuda available: False

# %%
import monai, torchio, nibabel
print("monai version:", monai.__version__)
print("torchio ok")
print("nibabel ok")
# Out:
# monai version: 1.5.1
# torchio ok
# nibabel ok
